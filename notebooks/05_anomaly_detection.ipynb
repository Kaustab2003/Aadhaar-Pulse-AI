# %% [markdown]
# # 05. Anomaly Detection

# %%
import pandas as pd
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.models.anomaly_detection import detect_anomalies, specific_fraud_rules

processed_path = os.path.join("..", "data", "processed", "merged_master_table.csv")
df = pd.read_csv(processed_path)
df['date'] = pd.to_datetime(df['date'])

# Run Detection
df_anom = detect_anomalies(df, contamination=0.02)
df_anom = specific_fraud_rules(df_anom)

# Show Anomalies
anomalies = df_anom[df_anom['is_anomaly'] == True]
print(f"Total Anomalies Detected: {len(anomalies)}")
display(anomalies[['date', 'state', 'district', 'total_updates', 'anomaly_score']].head(10))

# %% [markdown]
# ### Visualizing Anomalies
# Scatter plot to visualize normal vs anomalous points based on Enrolment vs Updates.

# %%
import plotly.express as px

fig = px.scatter(
    df_anom, 
    x="total_enrolment", 
    y="total_updates", 
    color="is_anomaly", 
    hover_data=["district", "state"],
    title="Anomaly Detection: Updates vs Enrolments",
    color_discrete_map={True: 'red', False: 'blue'}
)
fig.show()
